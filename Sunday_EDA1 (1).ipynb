# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('Sleep_health_and_lifestyle_dataset.csv')
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
df.shape
# Out:
# (374, 13)

# %%
df.dtypes
# Out:
# Person ID                    int64
# Gender                      object
# Age                          int64
# Occupation                  object
# Sleep Duration             float64
# Quality of Sleep             int64
# Physical Activity Level      int64
# Stress Level                 int64
# BMI Category                object
# Blood Pressure              object
# Heart Rate                   int64
# Daily Steps                  int64
# Sleep Disorder              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Person ID                    0
# Gender                       0
# Age                          0
# Occupation                   0
# Sleep Duration               0
# Quality of Sleep             0
# Physical Activity Level      0
# Stress Level                 0
# BMI Category                 0
# Blood Pressure               0
# Heart Rate                   0
# Daily Steps                  0
# Sleep Disorder             219
# dtype: int64

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df['Sleep Disorder']=df['Sleep Disorder'].fillna(df['Sleep Disorder'].mode()[0])
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.isnull().sum()
# Out:
# Person ID                  0
# Gender                     0
# Age                        0
# Occupation                 0
# Sleep Duration             0
# Quality of Sleep           0
# Physical Activity Level    0
# Stress Level               0
# BMI Category               0
# Blood Pressure             0
# Heart Rate                 0
# Daily Steps                0
# Sleep Disorder             0
# dtype: int64

# %%
from scipy import stats

# Select numerical columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# ===== BEFORE OUTLIER REMOVAL =====
plt.figure(figsize=(12, 6))
df[num_cols].boxplot()
plt.title("Before Outlier Removal (Boxplot)")
plt.ylabel("Value Range")
plt.xticks(rotation=45)
plt.show()

# ===== OUTLIER REMOVAL USING Z-SCORE =====
z = np.abs(stats.zscore(df[num_cols]))
threshold = 3
df = df[(z < threshold).all(axis=1)] 

# ===== AFTER OUTLIER REMOVAL =====
plt.figure(figsize=(12, 6))
df[num_cols].boxplot()
plt.title("After Outlier Removal (Boxplot)")
plt.ylabel("Value Range")
plt.xticks(rotation=45)
plt.show()

# ===== CHANGE SUMMARY =====
print(f"Rows remaining after outlier removal: {len(df)}")
# Out:
# c:\Users\DELL\OneDrive\Desktop\EDA3\myenv\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128230 (\N{PACKAGE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# Rows remaining after outlier removal: 365

# %%
df.shape
# Out:
# (365, 13)

# %%
def bmi_category(bmi):
    if bmi < 18.5:
        return 'Underweight'
    elif 18.5 <= bmi < 24.9:
        return 'Normal'
    elif 25 <= bmi < 29.9:
        return 'Overweight'
    else:
        return 'Obese'
if 'bmi' in df.columns:
    df['bmi_category'] = df['bmi'].apply(bmi_category)
df
# Out:
#      Person ID  Gender  Age         Occupation  Sleep Duration  \
# 0            1    Male   27  Software Engineer             6.1
# 1            2    Male   28             Doctor             6.2
# 2            3    Male   28             Doctor             6.2
# 6            7    Male   29            Teacher             6.3
# 7            8    Male   29             Doctor             7.8
# ..         ...     ...  ...                ...             ...
# 369        370  Female   59              Nurse             8.1
# 370        371  Female   59              Nurse             8.0
# 371        372  Female   59              Nurse             8.1
# 372        373  Female   59              Nurse             8.1
# 373        374  Female   59              Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 30))

for i, col in enumerate(df.columns, 1):
    plt.subplot(5, 3, i)
    if df[col].dtype in ['int64', 'float64']:
        plt.hist(df[col], bins=20, edgecolor='black')
        plt.xlabel(col)
        plt.ylabel("Count")
    else:
        df[col].value_counts().plot(kind='bar')
        plt.xlabel(col)
        plt.ylabel("Count")
    plt.title(f"Distribution of {col}")

plt.tight_layout()
plt.show()
# Select numeric columns
num_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Calculate skewness
skew_values = df[num_cols].skew()

print("Skewness for all numeric columns:")
print(skew_values)
# Out:
# Skewness for all numeric columns:
# Person ID                  0.010432
# Age                        0.272613
# Sleep Duration             0.050161
# Quality of Sleep          -0.111771
# Physical Activity Level    0.079544
# Stress Level               0.153126
# Heart Rate                 0.621591
# Daily Steps                0.335983
# dtype: float64

# %%
df_norm = df.copy()
skewed_cols = ['Heart Rate', 'Daily Steps']

for col in skewed_cols:
    df_norm[col] = np.log1p(df_norm[col])
print("Skewness after normalization:")
print(df_norm[skewed_cols].skew())

plt.figure(figsize=(12,5))
for i, col in enumerate(skewed_cols, 1):
    plt.subplot(1, 2, i)
    sns.histplot(df_norm[col], kde=True, color='skyblue')
    plt.title(f'{col} After Log Transformation')
plt.tight_layout()
plt.show()
# Out:
# Skewness after normalization:
# Heart Rate     0.483846
# Daily Steps   -0.108909
# dtype: float64

# %%
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.1f%%',startangle=90,colors=['#ff9999','#66b3ff'])
plt.title('Gender Distribution')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=df, x='Occupation', y='Sleep Duration', palette='viridis', ci=None)
plt.xticks(rotation=45)
plt.title("Average Sleep Duration by Occupation")
plt.ylabel("Average Sleep Duration (hours)")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18804\3422502361.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Occupation', y='Sleep Duration', palette='viridis', ci=None)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18804\3422502361.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Occupation', y='Sleep Duration', palette='viridis', ci=None)

# %%
sns.countplot(data=df, x='BMI Category', hue='Sleep Disorder', palette='coolwarm')
plt.title("BMI Category vs Sleep Disorder")
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.scatterplot(data=df, x='Sleep Duration', y='Stress Level', hue='Quality of Sleep', palette='cool')
plt.title("Sleep Duration vs Stress Level")
plt.show()

# %%
# ----- Print Averages -----
avg_sleep = round(df['Sleep Duration'].mean(), 2)
avg_stress = round(df['Stress Level'].mean(), 2)
avg_quality = round(df['Quality of Sleep'].mean(), 2)

print("Average Sleep Duration:", avg_sleep, "hours")
print("Average Stress Level:", avg_stress)
print("Average Quality of Sleep:", avg_quality)

# ----- Plot Averages -----
plt.figure(figsize=(10,6))
averages = [avg_sleep, avg_stress, avg_quality]
labels = ['Sleep Duration', 'Stress Level', 'Quality of Sleep']

bars = plt.bar(labels, averages, color=['pink','skyblue','#74c476'], edgecolor='orange')

# Add values on top of bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, round(yval,2), ha='center', fontsize=11)

plt.title("Average Sleep Metrics", fontsize=14, fontweight='bold')
plt.ylabel("Average Value")
plt.show()
# Out:
# Average Sleep Duration: 7.13 hours
# Average Stress Level: 5.38
# Average Quality of Sleep: 7.33

# %%
male_sleep = df[df['Gender'] == 'Male']['Sleep Duration']
female_sleep = df[df['Gender'] == 'Female']['Sleep Duration']
t_stat, p_val = stats.ttest_ind(male_sleep, female_sleep)
print("T-statistic:", t_stat)
print("P-value:", p_val)
if p_val < 0.05:
    print("Significant difference in Sleep Duration between genders.")
else:
    print("No significant difference between genders.")
# Out:
# T-statistic: -2.3006671537067134
# P-value: 0.02197673801600147
# Significant difference in Sleep Duration between genders.

# %%
sleep_gender_counts = df.groupby(['Gender', 'Sleep Disorder']).size().reset_index(name='Count')

# Plot grouped bar chart
plt.figure(figsize=(8,6))
sns.barplot(data=sleep_gender_counts, x='Gender', y='Count', hue='Sleep Disorder', palette='Set2')
plt.title('Sleep Disorder Distribution by Gender')
plt.ylabel('Number of People')
plt.show()
